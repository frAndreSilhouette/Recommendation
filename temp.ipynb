# %%
import pandas as pd
df = pd.read_feather("交易数据.feather")
print(df['campus_id'].unique())
df[df['campus_id']=='13']
# Out:
# ['18' '13' '107' '151' '38']
#                        sn  campus_zone_id campus_zone_name  \
# 21       2100001422688429              10          四川外国语大学
# 22       2100001422688429              10          四川外国语大学
# 23       2100001422689358              10          四川外国语大学
# 24       2100001422689551              10          四川外国语大学
# 33       2100001422737555              10          四川外国语大学
# ...                   ...             ...              ...
# 4401339  2100002660000315              10          四川外国语大学
# 4401340  2100002660000315              10          四川外国语大学
# 4401341  2100002660100342              10          四川外国语大学
# 4401342  2100002660100342              10          四川外国语大学
# 4401343  2100002660100342              10          四川外国语大学
#
#                                      store_id          store_sn  \
# 21       7afa08db-c323-45e6-ad05-d853d9052c4e  1580000007402917
# 22       7afa08db-c323-45e6-ad05-d853d9052c4e  1580000007402917
# ...
